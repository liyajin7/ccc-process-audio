# %%
# %pip install --user pandas boto3 botocore ffmpeg faster_whisper torch IPython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade numpy==1.26.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 51.5 MB/s eta 0:00:0031m87.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall ffmpeg
# %pip uninstall ffmpeg-python
# %pip install ffmpeg-python
# %ffmpeg --version
# Out:
# UsageError: Line magic function `%ffmpeg` not found.

# %%
import transcribe as tr

tr.play_s3_audio(
    'lsm-data-1', # bucket 
    'talk-radio/KNUS-AM/1730772237833852', # key
    0.0, # start_time
    80.0, # duration
    'S3-Access-Test' # aws_profile: 
)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
